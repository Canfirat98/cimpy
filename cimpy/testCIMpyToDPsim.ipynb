# %%
import cimpy
from cimpy import CIMpyToDPsim
from cimpy.CIMpyToDPsim import Domain
from cimpy.cgmes_v2_4_15.Base import short_profile_name
import os
from pathlib import Path

import sys
sys.path.insert(0,'/home/mmo-cya/dpsim/build')
import dpsimpy



example_dir = Path(os.path.join('../cimpy/examples/sampledata/CIGRE_MV')).resolve()

test_files = []
for file in example_dir.glob('*.xml'):
    test_files.append(str(file.absolute()))

imported_result = cimpy.cim_import(test_files, 'cgmes_v2_4_15')
# Out:
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# DL
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# EQ
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# SV
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# TP
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# TP
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# TP
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# TP
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# TP
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# TP
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# TP
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# TP
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# TP
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# TP
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# TP
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# TP
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# TP
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# TP
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTT
# TP
# CELU
# name
# CELU
# orientation
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# rotation
# CELU
# IdentifiedObject
# CELU
# Diagram
# CELU
# sequenceNumber
# CELU
# DiagramObject
# CELU
# xPosition
# CELU
# yPosition
# CELU
# nominalVoltage
# CELU
# nominalVoltage
# CELU
# name
# CELU
# Substation
# CELU
# BaseVoltage
# CELU
# name
# CELU
# Substation
# CELU
# BaseVoltage
# CELU
# name
# CELU
# Substation
# CELU
# BaseVoltage
# CELU
# name
# CELU
# Substation
# CELU
# BaseVoltage
# CELU
# name
# CELU
# Substation
# CELU
# BaseVoltage
# CELU
# name
# CELU
# Substation
# CELU
# BaseVoltage
# CELU
# name
# CELU
# Substation
# CELU
# BaseVoltage
# CELU
# name
# CELU
# Substation
# CELU
# BaseVoltage
# CELU
# name
# CELU
# Substation
# CELU
# BaseVoltage
# CELU
# name
# CELU
# Substation
# CELU
# BaseVoltage
# CELU
# name
# CELU
# Substation
# CELU
# BaseVoltage
# CELU
# name
# CELU
# Substation
# CELU
# BaseVoltage
# CELU
# name
# CELU
# Substation
# CELU
# BaseVoltage
# CELU
# name
# CELU
# Substation
# CELU
# BaseVoltage
# CELU
# name
# CELU
# Substation
# CELU
# BaseVoltage
# CELU
# name
# CELU
# Region
# CELU
# name
# CELU
# Region
# CELU
# name
# CELU
# Region
# CELU
# name
# CELU
# Region
# CELU
# name
# CELU
# Region
# CELU
# name
# CELU
# Region
# CELU
# name
# CELU
# Region
# CELU
# name
# CELU
# Region
# CELU
# name
# CELU
# Region
# CELU
# name
# CELU
# Region
# CELU
# name
# CELU
# Region
# CELU
# name
# CELU
# Region
# CELU
# name
# CELU
# Region
# CELU
# name
# CELU
# Region
# CELU
# name
# CELU
# Region
# CELU
# name
# CELU
# name
# CELU
# Region
# CELU
# name
# CELU
# acceptableDuration
# CELU
# direction
# CELU
# name
# CELU
# acceptableDuration
# CELU
# direction
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# ikSecond
# CELU
# maxInitialSymShCCurrent
# CELU
# maxR0ToX0Ratio
# CELU
# maxR1ToX1Ratio
# CELU
# maxZ0ToZ1Ratio
# CELU
# minInitialSymShCCurrent
# CELU
# minR0ToX0Ratio
# CELU
# minR1ToX1Ratio
# CELU
# Module NameType not implemented : 2 times
# Module Name not implemented : 65 times
# Missing NameType object with uuid: _d2995e50-380e-4f1b-beca-45ef75624ec5 : 1 times
# Missing Name object with uuid: _cbd79f33-9050-471d-baf8-330af085808e : 1 times
# Missing Name object with uuid: _42e42a88-94d6-431c-b0d8-f5ee1e1dc978 : 1 times
# Missing Name object with uuid: _87bfc15b-493d-4aec-ab02-75febd40a759 : 1 times
# Missing Name object with uuid: _ab4d5d67-276c-48cd-9ce0-227601ed2c7c : 1 times
# Referenced CurrentLimit [_32d6d32e-c3f0-43d4-8103-079a15594fc6] object missing. : 16 times
# Missing Name object with uuid: _ecea3b2d-e6c7-4850-9196-b7eae0d23775 : 1 times
# Missing Name object with uuid: _99244cd7-53a2-46df-99eb-6db15311a924 : 1 times
# Missing Name object with uuid: _14e6eb36-73d3-4cd3-8fe9-cd9e62dc50ce : 1 times
# Missing Name object with uuid: _35ec16e2-c578-4845-8d8a-83c2225be38e : 1 times
# Missing Name object with uuid: _b2aa8671-23cb-4b49-a3f6-b5be8b50c104 : 1 times
# Missing Name object with uuid: _5f5233dd-d7ec-4fbf-85f9-7290557ec0d3 : 1 times
# Missing Name object with uuid: _dc4cc669-af2a-42f9-9dcd-bdbadf5cfb75 : 1 times
# Missing Name object with uuid: _e10032ed-5c48-47db-bad8-91c80b2f10aa : 1 times
# Missing Name object with uuid: _ace32512-0a1c-4683-9fbc-6e2c39cc2a3f : 1 times
# Missing Name object with uuid: _804f450b-6a25-4458-aa13-4345b34523df : 1 times
# Missing Name object with uuid: _092f89de-0e82-49ab-9209-0f65b5fbdc29 : 1 times
# Missing Name object with uuid: _194288db-296e-4e91-97e3-cf78db8db04e : 1 times
# Missing Name object with uuid: _160428fc-6575-486c-a3fe-832fb09a0b43 : 1 times
# Missing Name object with uuid: _689dec99-3f73-4d5d-b0ad-ae327c2a0244 : 1 times
# Missing Name object with uuid: _4d10e296-6837-4211-b4db-d56fd0f2d6db : 1 times
# Missing Name object with uuid: _2fcee2f4-5ec2-4245-b837-5e94dbf4391e : 1 times
# Missing Name object with uuid: _eceafa25-f29a-40af-ac10-f2ea4bf3f728 : 1 times
# Missing Name object with uuid: _03a51b37-8384-49a1-80d0-71300f3ec061 : 1 times
# Missing Name object with uuid: _1b25df43-ef93-489b-8111-8cd41238b2ef : 1 times
# Missing Name object with uuid: _7eab8462-3f48-4f2d-9364-dfad57f32d4b : 1 times
# Missing Name object with uuid: _0717225b-10b7-411f-a6e9-ed52228c72da : 1 times
# Missing Name object with uuid: _b79caded-b000-41f5-8819-3ed537de80d2 : 1 times
# Missing Name object with uuid: _f69ebe62-bf8f-446d-88fc-bd1bf1fa337a : 1 times
# Missing Name object with uuid: _a1ffb35b-6a6d-4e74-9cc8-80e8b8df6b08 : 1 times
# Missing Name object with uuid: _b082f077-9bea-4937-b158-93bd2b2cecdc : 1 times
# Missing Name object with uuid: _ac8232f1-f3c9-497a-8649-fc90ecd6895d : 1 times
# Missing Name object with uuid: _fffc0c14-fe5a-4872-88f9-fe7377580fc5 : 1 times
# Missing Name object with uuid: _a4923a1c-e669-481c-8d52-988c84855376 : 1 times
# Missing Name object with uuid: _5f58fca6-c9b8-4a48-89a0-5e3b5f09d650 : 1 times
# Missing Name object with uuid: _cb436e95-45fa-4d84-bed8-b3b8975352ab : 1 times
# Missing Name object with uuid: _9ee79681-9732-43e7-b91d-dfa89b19eb58 : 1 times
# Missing Name object with uuid: _2845a305-ad4f-4afd-904c-cd7704c389b3 : 1 times
# Missing Name object with uuid: _27bb80f8-4acf-4e17-9ff0-8b43ea1ce826 : 1 times
# Missing Name object with uuid: _647bc1e0-011a-4f15-90c8-c1e6fa58817f : 1 times
# Missing Name object with uuid: _faa5ae1f-b7e1-4951-a2ce-45e03897f83a : 1 times
# Missing Name object with uuid: _b7aed28d-2c2d-47dc-9876-3a81bf9d1529 : 1 times
# Missing Name object with uuid: _af72eba9-7af2-4808-9da4-432ff0849ea7 : 1 times
# Missing Name object with uuid: _41842f31-4adc-4b71-b50c-fc08a608ea29 : 1 times
# Missing Name object with uuid: _eb0a39a3-c2e0-41e9-8b68-527b1ef64493 : 1 times
# Missing Name object with uuid: _5285090f-646b-4562-ac11-cd1e66b4a97e : 1 times
# Missing Name object with uuid: _bd2862ac-da6e-4fca-89e2-ab793bf46e8a : 1 times
# Missing Name object with uuid: _0cfb3a99-5ddd-4cca-84d8-4d27bce35f12 : 1 times
# Missing Name object with uuid: _55cd4b1d-86ca-4dbb-a114-9354f5dc5c04 : 1 times
# Missing Name object with uuid: _6bdd0483-21e7-4327-90b3-d024b41b8528 : 1 times
# Missing Name object with uuid: _4881cf2a-f906-402d-a413-8a81215bd614 : 1 times
# Missing Name object with uuid: _80b08db8-7624-4c3d-abd8-7bcd195a605f : 1 times
# Missing Name object with uuid: _9d9a632c-94e9-458d-9e17-cceedd7098be : 1 times
# Missing Name object with uuid: _2afef3f8-920d-43b2-9fbd-74f64b0959bf : 1 times
# Missing Name object with uuid: _03306aa5-d343-442b-8772-078802df53e8 : 1 times
# Missing Name object with uuid: _01fbc78e-84af-40b8-95ab-dfcf3229d9af : 1 times
# Missing Name object with uuid: _c32fc9a9-36d9-4e4b-acf4-45632379377e : 1 times
# Missing Name object with uuid: _4088ebe7-3c1f-4595-89d5-c630c4433202 : 1 times
# Missing Name object with uuid: _b0908a9d-ef41-4d5d-b48a-88e7622a6946 : 1 times
# Missing Name object with uuid: _408c391a-669a-4c14-b542-602673840a7a : 1 times
# Missing Name object with uuid: _32fc99f8-3df6-4b76-8a77-b2ed42c91de6 : 1 times
# Missing Name object with uuid: _08968764-bbcb-4f6f-b584-45fb39faf065 : 1 times
# Missing Name object with uuid: _7f46d992-6ce4-4ff1-b3ae-d94e1ed16610 : 1 times
# Missing Name object with uuid: _f2078bfb-5199-43ab-8fd8-5b71e17b5389 : 1 times
# Missing Name object with uuid: _45609fd5-85e4-43c4-94a4-a4ea57953170 : 1 times
# Missing Name object with uuid: _cd6e35d8-2393-48aa-bb34-dda99137f2f9 : 1 times
# Missing Name object with uuid: _8adc495a-f580-4773-a65d-795a40ab5fb3 : 1 times
# Missing NameType object with uuid: _9ab60b89-1c09-4ded-a42f-0ebd0eef8930 : 1 times
# minZ0ToZ1Ratio
# CELU
# voltageFactor
# CELU
# referencePriority
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# r
# CELU
# x
# CELU
# bch
# CELU
# length
# CELU
# gch
# CELU
# aggregate
# CELU
# BaseVoltage
# CELU
# r0
# CELU
# x0
# CELU
# b0ch
# CELU
# g0ch
# CELU
# shortCircuitEndTemperature
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# Equipment
# CELU
# Terminal
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# r
# CELU
# x
# CELU
# bch
# CELU
# length
# CELU
# gch
# CELU
# aggregate
# CELU
# BaseVoltage
# CELU
# r0
# CELU
# x0
# CELU
# b0ch
# CELU
# g0ch
# CELU
# shortCircuitEndTemperature
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# Equipment
# CELU
# Terminal
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# r
# CELU
# x
# CELU
# bch
# CELU
# length
# CELU
# gch
# CELU
# aggregate
# CELU
# BaseVoltage
# CELU
# r0
# CELU
# x0
# CELU
# b0ch
# CELU
# g0ch
# CELU
# shortCircuitEndTemperature
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# Equipment
# CELU
# Terminal
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# r
# CELU
# x
# CELU
# bch
# CELU
# length
# CELU
# gch
# CELU
# aggregate
# CELU
# BaseVoltage
# CELU
# r0
# CELU
# x0
# CELU
# b0ch
# CELU
# g0ch
# CELU
# shortCircuitEndTemperature
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# Equipment
# CELU
# Terminal
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# r
# CELU
# x
# CELU
# bch
# CELU
# length
# CELU
# gch
# CELU
# aggregate
# CELU
# BaseVoltage
# CELU
# r0
# CELU
# x0
# CELU
# b0ch
# CELU
# g0ch
# CELU
# shortCircuitEndTemperature
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# Equipment
# CELU
# Terminal
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# r
# CELU
# x
# CELU
# bch
# CELU
# length
# CELU
# gch
# CELU
# aggregate
# CELU
# BaseVoltage
# CELU
# r0
# CELU
# x0
# CELU
# b0ch
# CELU
# g0ch
# CELU
# shortCircuitEndTemperature
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# Equipment
# CELU
# Terminal
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# r
# CELU
# x
# CELU
# bch
# CELU
# length
# CELU
# gch
# CELU
# aggregate
# CELU
# BaseVoltage
# CELU
# r0
# CELU
# x0
# CELU
# b0ch
# CELU
# g0ch
# CELU
# shortCircuitEndTemperature
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# Equipment
# CELU
# Terminal
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# r
# CELU
# x
# CELU
# bch
# CELU
# length
# CELU
# gch
# CELU
# aggregate
# CELU
# BaseVoltage
# CELU
# r0
# CELU
# x0
# CELU
# b0ch
# CELU
# g0ch
# CELU
# shortCircuitEndTemperature
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# Equipment
# CELU
# Terminal
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# r
# CELU
# x
# CELU
# bch
# CELU
# length
# CELU
# gch
# CELU
# aggregate
# CELU
# BaseVoltage
# CELU
# r0
# CELU
# x0
# CELU
# b0ch
# CELU
# g0ch
# CELU
# shortCircuitEndTemperature
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# Equipment
# CELU
# Terminal
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# r
# CELU
# x
# CELU
# bch
# CELU
# length
# CELU
# gch
# CELU
# aggregate
# CELU
# BaseVoltage
# CELU
# r0
# CELU
# x0
# CELU
# b0ch
# CELU
# g0ch
# CELU
# shortCircuitEndTemperature
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# Equipment
# CELU
# Terminal
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# r
# CELU
# x
# CELU
# bch
# CELU
# length
# CELU
# gch
# CELU
# aggregate
# CELU
# BaseVoltage
# CELU
# r0
# CELU
# x0
# CELU
# b0ch
# CELU
# g0ch
# CELU
# shortCircuitEndTemperature
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# Equipment
# CELU
# Terminal
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# r
# CELU
# x
# CELU
# bch
# CELU
# length
# CELU
# gch
# CELU
# aggregate
# CELU
# BaseVoltage
# CELU
# r0
# CELU
# x0
# CELU
# b0ch
# CELU
# g0ch
# CELU
# shortCircuitEndTemperature
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# Equipment
# CELU
# Terminal
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# beforeShCircuitHighestOperatingVoltage
# CELU
# beforeShCircuitHighestOperatingCurrent
# CELU
# beforeShortCircuitAnglePf
# CELU
# highSideMinOperatingU
# CELU
# isPartOfGeneratorUnit
# CELU
# operationalValuesConsidered
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# r
# CELU
# x
# CELU
# b
# CELU
# g
# CELU
# r0
# CELU
# x0
# CELU
# b0
# CELU
# g0
# CELU
# rground
# CELU
# xground
# CELU
# ratedS
# CELU
# ratedU
# CELU
# endNumber
# CELU
# phaseAngleClock
# CELU
# grounded
# CELU
# connectionKind
# CELU
# BaseVoltage
# CELU
# PowerTransformer
# CELU
# Terminal
# CELU
# name
# CELU
# Equipment
# CELU
# Terminal
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# r
# CELU
# x
# CELU
# b
# CELU
# g
# CELU
# r0
# CELU
# x0
# CELU
# b0
# CELU
# g0
# CELU
# rground
# CELU
# xground
# CELU
# ratedS
# CELU
# ratedU
# CELU
# endNumber
# CELU
# phaseAngleClock
# CELU
# grounded
# CELU
# connectionKind
# CELU
# BaseVoltage
# CELU
# PowerTransformer
# CELU
# Terminal
# CELU
# name
# CELU
# Equipment
# CELU
# Terminal
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# aggregate
# CELU
# EquipmentContainer
# CELU
# beforeShCircuitHighestOperatingVoltage
# CELU
# beforeShCircuitHighestOperatingCurrent
# CELU
# beforeShortCircuitAnglePf
# CELU
# highSideMinOperatingU
# CELU
# isPartOfGeneratorUnit
# CELU
# operationalValuesConsidered
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# r
# CELU
# x
# CELU
# b
# CELU
# g
# CELU
# r0
# CELU
# x0
# CELU
# b0
# CELU
# g0
# CELU
# rground
# CELU
# xground
# CELU
# ratedS
# CELU
# ratedU
# CELU
# endNumber
# CELU
# phaseAngleClock
# CELU
# grounded
# CELU
# connectionKind
# CELU
# BaseVoltage
# CELU
# PowerTransformer
# CELU
# Terminal
# CELU
# name
# CELU
# Equipment
# CELU
# Terminal
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# sequenceNumber
# CELU
# ConductingEquipment
# CELU
# name
# CELU
# r
# CELU
# x
# CELU
# b
# CELU
# g
# CELU
# r0
# CELU
# x0
# CELU
# b0
# CELU
# g0
# CELU
# rground
# CELU
# xground
# CELU
# ratedS
# CELU
# ratedU
# CELU
# endNumber
# CELU
# phaseAngleClock
# CELU
# grounded
# CELU
# connectionKind
# CELU
# BaseVoltage
# CELU
# PowerTransformer
# CELU
# Terminal
# CELU
# name
# CELU
# Equipment
# CELU
# Terminal
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# name
# CELU
# value
# CELU
# OperationalLimitSet
# CELU
# OperationalLimitType
# CELU
# v
# CELU
# angle
# CELU
# TopologicalNode
# CELU
# v
# CELU
# angle
# CELU
# TopologicalNode
# CELU
# v
# CELU
# angle
# CELU
# TopologicalNode
# CELU
# v
# CELU
# angle
# CELU
# TopologicalNode
# CELU
# v
# CELU
# angle
# CELU
# TopologicalNode
# CELU
# v
# CELU
# angle
# CELU
# TopologicalNode
# CELU
# v
# CELU
# angle
# CELU
# TopologicalNode
# CELU
# v
# CELU
# angle
# CELU
# TopologicalNode
# CELU
# v
# CELU
# angle
# CELU
# TopologicalNode
# CELU
# v
# CELU
# angle
# CELU
# TopologicalNode
# CELU
# v
# CELU
# angle
# CELU
# TopologicalNode
# CELU
# v
# CELU
# angle
# CELU
# TopologicalNode
# CELU
# v
# CELU
# angle
# CELU
# TopologicalNode
# CELU
# v
# CELU
# angle
# CELU
# TopologicalNode
# CELU
# v
# CELU
# angle
# CELU
# TopologicalNode
# CELU
# p
# CELU
# q
# CELU
# Terminal
# CELU
# p
# CELU
# q
# CELU
# Terminal
# CELU
# p
# CELU
# q
# CELU
# Terminal
# CELU
# p
# CELU
# q
# CELU
# Terminal
# CELU
# p
# CELU
# q
# CELU
# Terminal
# CELU
# p
# CELU
# q
# CELU
# Terminal
# CELU
# p
# CELU
# q
# CELU
# Terminal
# CELU
# p
# CELU
# q
# CELU
# Terminal
# CELU
# p
# CELU
# q
# CELU
# Terminal
# CELU
# p
# CELU
# q
# CELU
# Terminal
# CELU
# p
# CELU
# q
# CELU
# Terminal
# CELU
# p
# CELU
# q
# CELU
# Terminal
# CELU
# p
# CELU
# q
# CELU
# Terminal
# CELU
# p
# CELU
# q
# CELU
# Terminal
# CELU
# p
# CELU
# q
# CELU
# Terminal
# CELU
# p
# CELU
# q
# CELU
# Terminal
# CELU
# p
# CELU
# q
# CELU
# Terminal
# CELU
# p
# CELU
# q
# CELU
# Terminal
# CELU
# name
# CELU
# BaseVoltage
# CELU
# ConnectivityNodeContainer
# CELU
# name
# CELU
# BaseVoltage
# CELU
# ConnectivityNodeContainer
# CELU
# name
# CELU
# BaseVoltage
# CELU
# ConnectivityNodeContainer
# CELU
# name
# CELU
# BaseVoltage
# CELU
# ConnectivityNodeContainer
# CELU
# name
# CELU
# BaseVoltage
# CELU
# ConnectivityNodeContainer
# CELU
# name
# CELU
# BaseVoltage
# CELU
# ConnectivityNodeContainer
# CELU
# name
# CELU
# BaseVoltage
# CELU
# ConnectivityNodeContainer
# CELU
# name
# CELU
# BaseVoltage
# CELU
# ConnectivityNodeContainer
# CELU
# name
# CELU
# BaseVoltage
# CELU
# ConnectivityNodeContainer
# CELU
# name
# CELU
# BaseVoltage
# CELU
# ConnectivityNodeContainer
# CELU
# name
# CELU
# BaseVoltage
# CELU
# ConnectivityNodeContainer
# CELU
# name
# CELU
# BaseVoltage
# CELU
# ConnectivityNodeContainer
# CELU
# name
# CELU
# BaseVoltage
# CELU
# ConnectivityNodeContainer
# CELU
# name
# CELU
# BaseVoltage
# CELU
# ConnectivityNodeContainer
# CELU
# name
# CELU
# BaseVoltage
# CELU
# ConnectivityNodeContainer
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CELU
# connected
# CELU
# TopologicalNode
# CIM object Diagram created : 1 times
# CIM object DiagramObject created : 71 times
# CIM object DiagramObjectPoint created : 126 times
# CIM object BaseVoltage created : 2 times
# CIM object VoltageLevel created : 15 times
# CIM object Substation created : 15 times
# CIM object GeographicalRegion created : 1 times
# CIM object SubGeographicalRegion created : 1 times
# CIM object OperationalLimitType created : 2 times
# CIM object EnergyConsumer created : 18 times
# CIM object Terminal created : 47 times
# CIM object ExternalNetworkInjection created : 1 times
# CIM object ACLineSegment created : 12 times
# CIM object OperationalLimitSet created : 16 times
# CIM object CurrentLimit created : 48 times
# CIM object PowerTransformer created : 2 times
# CIM object PowerTransformerEnd created : 4 times
# CIM object SvVoltage created : 15 times
# CIM object SvPowerFlow created : 18 times
# CIM object TopologicalNode created : 15 times
# Created totally 430 CIM objects in 0.3434937000274658s

# %%
system_test , comp_test = CIMpyToDPsim.CIMpyToDPsim(imported_result, Domain.PF)

system_test
# Out:
# [16:22:01.130603 L12-13 warning] Zero value for Conductance, setting default value of G=1e-06 [S]
# [16:22:01.130900 L13-14 warning] Zero value for Conductance, setting default value of G=1e-06 [S]
# [16:22:01.131202 L1-2 warning] Zero value for Conductance, setting default value of G=1e-06 [S]
# [16:22:01.131479 L2-3 warning] Zero value for Conductance, setting default value of G=1e-06 [S]
# [16:22:01.131771 L3-4 warning] Zero value for Conductance, setting default value of G=1e-06 [S]
# [16:22:01.132035 L4-5 warning] Zero value for Conductance, setting default value of G=1e-06 [S]
# [16:22:01.132306 L5-6 warning] Zero value for Conductance, setting default value of G=1e-06 [S]
# [16:22:01.132587 L3-8 warning] Zero value for Conductance, setting default value of G=1e-06 [S]
# [16:22:01.132866 L10-11 warning] Zero value for Conductance, setting default value of G=1e-06 [S]
# [16:22:01.133134 L9-10 warning] Zero value for Conductance, setting default value of G=1e-06 [S]
# [16:22:01.133402 L8-9 warning] Zero value for Conductance, setting default value of G=1e-06 [S]
# [16:22:01.133707 L7-8 warning] Zero value for Conductance, setting default value of G=1e-06 [S]
# Warning: some nodes with margin (3.20,3.20) touch - falling back to straight line edges

# %%
comp_test['TR1']
# Out:
# {'Element': <dpsimpy.sp.ph1.Transformer at 0x7f9608e543b0>,
#  'Nodes': [<dpsimpy.dp.SimNode at 0x7f9608e545f0>,
#   <dpsimpy.dp.SimNode at 0x7f9608e54f70>]}

# %%
system= dpsimpy.SystemTopology(60)


reader = dpsimpy.CIMReader("system")
system = reader.loadCIM(60, test_files, dpsimpy.Domain.SP, dpsimpy.PhaseType.Single, dpsimpy.GeneratorType.PVNode)

system
# Out:
# Warning: could not assign attribute with name: cim:NameType.name and value: description
# Couldn't find cim:OperationalLimit.OperationalLimitType with value: _32d6d32e-c3f0-43d4-8103-079a15594fc6 in RDFMap.
# Couldn't find cim:OperationalLimit.OperationalLimitType with value: _32d6d32e-c3f0-43d4-8103-079a15594fc6 in RDFMap.
# Couldn't find cim:OperationalLimit.OperationalLimitType with value: _32d6d32e-c3f0-43d4-8103-079a15594fc6 in RDFMap.
# Couldn't find cim:OperationalLimit.OperationalLimitType with value: _32d6d32e-c3f0-43d4-8103-079a15594fc6 in RDFMap.
# Couldn't find cim:OperationalLimit.OperationalLimitType with value: _32d6d32e-c3f0-43d4-8103-079a15594fc6 in RDFMap.
# Warning: could not assign attribute with name: cim:Name.name and value: NETWORK-FEEDER:
# Warning: could not assign attribute with name: cim:Name.name and value: Ratings
# Warning: could not assign class of unrecognised type cim:Name.NameType.
# Warning: could not assign class of unrecognised type cim:Name.IdentifiedObject.
# CIMContentHandler: Note: Cannot resolve following RDF relationship: cim:OperationalLimit.OperationalLimitType 'ShortTerm' = '_32d6d32e-c3f0-43d4-8103-079a15594fc6'
# CIMContentHandler: Note: Cannot resolve following RDF relationship: cim:OperationalLimit.OperationalLimitType 'ShortTerm' = '_32d6d32e-c3f0-43d4-8103-079a15594fc6'
# CIMContentHandler: Note: Cannot resolve following RDF relationship: cim:OperationalLimit.OperationalLimitType 'ShortTerm' = '_32d6d32e-c3f0-43d4-8103-079a15594fc6'
# CIMContentHandler: Note: Cannot resolve following RDF relationship: cim:OperationalLimit.OperationalLimitType 'ShortTerm' = '_32d6d32e-c3f0-43d4-8103-079a15594fc6'
# CIMContentHandler: Note: Cannot resolve following RDF relationship: cim:OperationalLimit.OperationalLimitType 'ShortTerm' = '_32d6d32e-c3f0-43d4-8103-079a15594fc6'
# CIMContentHandler: Note: Cannot resolve following RDF relationship: cim:OperationalLimit.OperationalLimitType 'ShortTerm' = '_32d6d32e-c3f0-43d4-8103-079a15594fc6'
# CIMContentHandler: Note: Cannot resolve following RDF relationship: cim:OperationalLimit.OperationalLimitType 'ShortTerm' = '_32d6d32e-c3f0-43d4-8103-079a15594fc6'
# CIMContentHandler: Note: Cannot resolve following RDF relationship: cim:OperationalLimit.OperationalLimitType 'ShortTerm' = '_32d6d32e-c3f0-43d4-8103-079a15594fc6'
# CIMContentHandler: Note: Cannot resolve following RDF relationship: cim:OperationalLimit.OperationalLimitType 'ShortTerm' = '_32d6d32e-c3f0-43d4-8103-079a15594fc6'
# CIMContentHandler: Note: Cannot resolve following RDF relationship: cim:OperationalLimit.OperationalLimitType 'ShortTerm' = '_32d6d32e-c3f0-43d4-8103-079a15594fc6'
# CIMContentHandler: Note: Cannot resolve following RDF relationship: cim:OperationalLimit.OperationalLimitType 'ShortTerm' = '_32d6d32e-c3f0-43d4-8103-079a15594fc6'
# CIMContentHandler: Note: Cannot resolve following RDF relationship: cim:OperationalLimit.OperationalLimitType 'ShortTerm' = '_32d6d32e-c3f0-43d4-8103-079a15594fc6'
# CIMContentHandler: Note: Cannot resolve following RDF relationship: cim:OperationalLimit.OperationalLimitType 'ShortTerm' = '_32d6d32e-c3f0-43d4-8103-079a15594fc6'
# CIMContentHandler: Note: Cannot resolve following RDF relationship: cim:OperationalLimit.OperationalLimitType 'ShortTerm' = '_32d6d32e-c3f0-43d4-8103-079a15594fc6'
# CIMContentHandler: Note: Cannot resolve following RDF relationship: cim:OperationalLimit.OperationalLimitType 'ShortTerm' = '_32d6d32e-c3f0-43d4-8103-079a15594fc6'
# CIMContentHandler: Note: Cannot resolve following RDF relationship: cim:OperationalLimit.OperationalLimitType 'ShortTerm' = '_32d6d32e-c3f0-43d4-8103-079a15594fc6'
# CIMContentHandler: Note: 16 out of 774 tasks remain unresolved!
# Couldn't find cim:OperationalLimit.OperationalLimitType with value: _32d6d32e-c3f0-43d4-8103-079a15594fc6 in RDFMap.
# Couldn't find cim:OperationalLimit.OperationalLimitType with value: _32d6d32e-c3f0-43d4-8103-079a15594fc6 in RDFMap.
# Couldn't find cim:OperationalLimit.OperationalLimitType with value: _32d6d32e-c3f0-43d4-8103-079a15594fc6 in RDFMap.
# Couldn't find cim:OperationalLimit.OperationalLimitType with value: _32d6d32e-c3f0-43d4-8103-079a15594fc6 in RDFMap.
# Couldn't find cim:OperationalLimit.OperationalLimitType with value: _32d6d32e-c3f0-43d4-8103-079a15594fc6 in RDFMap.
# Couldn't find cim:OperationalLimit.OperationalLimitType with value: _32d6d32e-c3f0-43d4-8103-079a15594fc6 in RDFMap.
# Couldn't find cim:OperationalLimit.OperationalLimitType with value: _32d6d32e-c3f0-43d4-8103-079a15594fc6 in RDFMap.
# Couldn't find cim:OperationalLimit.OperationalLimitType with value: _32d6d32e-c3f0-43d4-8103-079a15594fc6 in RDFMap.
# Couldn't find cim:OperationalLimit.OperationalLimitType with value: _32d6d32e-c3f0-43d4-8103-079a15594fc6 in RDFMap.
# Couldn't find cim:OperationalLimit.OperationalLimitType with value: _32d6d32e-c3f0-43d4-8103-079a15594fc6 in RDFMap.
# Couldn't find cim:OperationalLimit.OperationalLimitType with value: _32d6d32e-c3f0-43d4-8103-079a15594fc6 in RDFMap.
# Warning: some nodes with margin (3.20,3.20) touch - falling back to straight line edges

# %%
name = "CIGRE_Test"
dpsimpy.Logger.set_log_dir("logs/" + name)

    ### Simulation
sim = dpsimpy.Simulation(name, dpsimpy.LogLevel.debug)
sim.set_system(system_test)
sim.set_domain(dpsimpy.Domain.SP)
sim.set_solver(dpsimpy.Solver.NRP)
sim.set_solver_component_behaviour(dpsimpy.SolverBehaviour.Initialization)
sim.set_time_step(0.1)
sim.set_final_time(0.5)
sim.run()
# Out:
# [16:25:07.661640 CIGRE_Test info] Initialize simulation: CIGRE_Test
# [16:25:07.662388 CIGRE_Test_PF_Solver warning] No suitable quantity found for setting mBaseApparentPower. Using 100000000 VA.
# [16:25:07.691434 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N12
# [16:25:07.691442 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N12
# [16:25:07.691458 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N13
# [16:25:07.691466 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N14
# [16:25:07.691469 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N14
# [16:25:07.691478 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N0
# [16:25:07.691488 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N1
# [16:25:07.691491 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N1
# [16:25:07.691502 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N3
# [16:25:07.691505 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N3
# [16:25:07.691512 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N4
# [16:25:07.691520 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N5
# [16:25:07.691527 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N11
# [16:25:07.691534 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N10
# [16:25:07.691537 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N10
# [16:25:07.691544 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N8
# [16:25:07.691551 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N7
# [16:25:07.691579 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N6
# [16:25:07.691588 CIGRE_Test_PF_Solver warning] Unable to get base voltage at N9
# [16:25:07.692111 CIGRE_Test info] Scheduling tasks.
# [16:25:07.692276 CIGRE_Test info] Scheduling done.
# [16:25:07.692279 CIGRE_Test info] Opening interfaces.
# [16:25:07.692281 CIGRE_Test info] Start synchronization with remotes on interfaces
# [16:25:07.692283 CIGRE_Test info] Synchronized simulation start with remotes
# [16:25:07.692286 CIGRE_Test info] Start simulation: CIGRE_Test
# [16:25:07.692292 CIGRE_Test info] Time step: 1.000000e-01
# [16:25:07.692295 CIGRE_Test info] Final time: 5.000000e-01
# [16:25:07.760017 CIGRE_Test info] Simulation calculation time: 0.067716
# [16:25:07.760026 CIGRE_Test info] Simulation finished.

# %%
#system.components

# %%
res = imported_result["topology"]

for i in res:
    if isinstance(res[i], cimpy.cgmes_v2_4_15.EnergyConsumer) or isinstance(res[i], cimpy.cgmes_v2_4_15.ConformLoad):
            # Energy Consumer
        print( i, " is of type:", type(res[i]))
# Out:
# Load7-I  is of type: <class 'cimpy.cgmes_v2_4_15.EnergyConsumer.EnergyConsumer'>
# Load14-H  is of type: <class 'cimpy.cgmes_v2_4_15.EnergyConsumer.EnergyConsumer'>
# Load13-I  is of type: <class 'cimpy.cgmes_v2_4_15.EnergyConsumer.EnergyConsumer'>
# Load12-H  is of type: <class 'cimpy.cgmes_v2_4_15.EnergyConsumer.EnergyConsumer'>
# Load1-I  is of type: <class 'cimpy.cgmes_v2_4_15.EnergyConsumer.EnergyConsumer'>
# Load3-H  is of type: <class 'cimpy.cgmes_v2_4_15.EnergyConsumer.EnergyConsumer'>
# Load3-I  is of type: <class 'cimpy.cgmes_v2_4_15.EnergyConsumer.EnergyConsumer'>
# Load10-I  is of type: <class 'cimpy.cgmes_v2_4_15.EnergyConsumer.EnergyConsumer'>
# Load1-H  is of type: <class 'cimpy.cgmes_v2_4_15.EnergyConsumer.EnergyConsumer'>
# Load12-I  is of type: <class 'cimpy.cgmes_v2_4_15.EnergyConsumer.EnergyConsumer'>
# Load14-I  is of type: <class 'cimpy.cgmes_v2_4_15.EnergyConsumer.EnergyConsumer'>
# Load5_H  is of type: <class 'cimpy.cgmes_v2_4_15.EnergyConsumer.EnergyConsumer'>
# Load4-H  is of type: <class 'cimpy.cgmes_v2_4_15.EnergyConsumer.EnergyConsumer'>
# Load11-H  is of type: <class 'cimpy.cgmes_v2_4_15.EnergyConsumer.EnergyConsumer'>
# Load10-H  is of type: <class 'cimpy.cgmes_v2_4_15.EnergyConsumer.EnergyConsumer'>
# Load9-I  is of type: <class 'cimpy.cgmes_v2_4_15.EnergyConsumer.EnergyConsumer'>
# Load6-H  is of type: <class 'cimpy.cgmes_v2_4_15.EnergyConsumer.EnergyConsumer'>
# Load8-H  is of type: <class 'cimpy.cgmes_v2_4_15.EnergyConsumer.EnergyConsumer'>

# %%
for comp in res.values():
    if isinstance(comp, cimpy.cgmes_v2_4_15.ExternalNetworkInjection):
        print (comp.mRID, "is ",type(comp))
        print(comp)
        if comp.RegulatingControl != None:
            print("JA")
        else:
            print("NEIN")
# Out:
# HV-Netz is  <class 'cimpy.cgmes_v2_4_15.ExternalNetworkInjection.ExternalNetworkInjection'>
# class=ExternalNetworkInjection
# DiagramObjects=list
# mRID=HV-Netz
# name=HV-Netz
# description=
# energyIdentCodeEic=
# shortName=
# Controls=list
# Measurements=list
# Location=None
# aggregate=False
# EquipmentContainer=class=VoltageLevel
# DiagramObjects=list
# mRID=_2a7c745b-de30-4863-88ba-dcbe73f806df
# name=41
# description=
# energyIdentCodeEic=
# shortName=
# Controls=list
# Measurements=list
# Location=None
# ConnectivityNodes=list
# TopologicalNode=[<cimpy.cgmes_v2_4_15.TopologicalNode.TopologicalNode object at 0x7f9608e3d7c0>]
# Equipments=list
# BaseVoltage=class=BaseVoltage
# DiagramObjects=list
# mRID=_a55f97f1-c485-414c-a845-678fe1eb19cf
# name=
# description=
# energyIdentCodeEic=
# shortName=
# nominalVoltage=110.0
# ConductingEquipment=list
# VoltageLevel=[<cimpy.cgmes_v2_4_15.VoltageLevel.VoltageLevel object at 0x7f9608ec9c40>]
# TransformerEnds=list
# TopologicalNode=[<cimpy.cgmes_v2_4_15.TopologicalNode.TopologicalNode object at 0x7f9608e3d7c0>]
#
# Substation=class=Substation
# DiagramObjects=list
# mRID=_3FA2-2E-F1-00000000000000003431
# name=N0
# description=
# energyIdentCodeEic=
# shortName=
# Controls=list
# Measurements=list
# Location=None
# ConnectivityNodes=list
# TopologicalNode=list
# Equipments=list
# DCConverterUnit=list
# Region=class=SubGeographicalRegion
# DiagramObjects=list
# mRID=_33f5b8ba-2a5d-445d-85e2-714736e3087d
# name=Zone 1
# description=
# energyIdentCodeEic=
# shortName=
# DCLines=list
# Region=class=GeographicalRegion
# DiagramObjects=list
# mRID=_6ed30243-96d0-4ff3-9d4c-ef272ceb2bb0
# name=Area 1
# description=
# energyIdentCodeEic=
# shortName=
# Regions=list
#
# Lines=list
# Substations=list
#
# VoltageLevels=list
#
# highVoltageLimit=0.0
# lowVoltageLimit=0.0
# Bays=list
#
# OperationalLimitSet=list
# BaseVoltage=None
# Terminals=list
# SvStatus=None
# RegulatingControl=None
# controlEnabled=False
# governorSCD=0.0
# maxP=0.0
# maxQ=0.0
# minP=0.0
# minQ=0.0
# ikSecond=True
# maxInitialSymShCCurrent=0.0
# maxR0ToX0Ratio=0.0
# maxR1ToX1Ratio=0.0
# maxZ0ToZ1Ratio=0.0
# minInitialSymShCCurrent=0.0
# minR0ToX0Ratio=0.0
# minR1ToX1Ratio=0.0
# minZ0ToZ1Ratio=0.0
# voltageFactor=1.0
# referencePriority=1
# p=0.0
# q=0.0
#
# NEIN

# %%
for compn in system.components:
    if isinstance(compn, dpsimpy.sp.ph1.NetworkInjection):
        print(compn)

K = dpsimpy.sp.ph1.PiLine("Inj")
print(K)
K.set_parameters
# Out:
# Attribute list for object with name HV-Netz:
# name                          type                size           value
# -----------------------------------------------------------------------------------------------
# V_ref                         Complex                            0.000000<0.000000
# V_set                         Real                               110000.000000
# V_set_pu                      Real                               1.000000
# f_src                         Real                               0.000000
# i_intf                        MatrixComplex       1x1            [...]
# name                          String                             "HV-Netz"
# p_inj                         Real                               0.000000
# q_inj                         Real                               0.000000
# right_vector                  MatrixReal          0x0            [...]
# uid                           String                             "HV-Netz"
# v_intf                        MatrixComplex       1x1            [...]
#
# Attribute list for object with name Inj:
# name                          type                size           value
# -----------------------------------------------------------------------------------------------
# C_parallel                    Real                               0.000000
# G_parallel                    Real                               0.000000
# L_series                      Real                               0.000000
# R_series                      Real                               0.000000
# base_Voltage                  Real                               0.000000
# current_vector                MatrixComplex       2x1            [...]
# i_intf                        MatrixComplex       1x1            [...]
# name                          String                             "Inj"
# p_branch_vector               MatrixReal          2x1            [...]
# p_inj                         Real                               0.000000
# q_branch_vector               MatrixReal          2x1            [...]
# q_inj                         Real                               0.000000
# right_vector                  MatrixReal          0x0            [...]
# uid                           String                             "Inj"
# v_intf                        MatrixComplex       1x1            [...]
# <bound method PyCapsule.set_parameters of <dpsimpy.sp.ph1.PiLine object at 0x7f9608e654b0>>

# %%
cimpy.cgmes_v2_4_15.BaseVoltage.possibleProfileList
cimpy.cgmes_v2_4_15.ACLineSegment.possibleProfileList
# Out:
# {'class': [0],
#  'bch': [0],
#  'gch': [0],
#  'r': [0],
#  'x': [0],
#  'b0ch': [0],
#  'g0ch': [0],
#  'r0': [0],
#  'shortCircuitEndTemperature': [0],
#  'x0': [0]}

# %%
print(res["N0"].Terminal[0].ConductingEquipment.mRID)


res["N12"].possibleProfileList
res["N12"].BaseVoltage.nominalVoltage
# Out:
# TR1
# 20.0

# %%
for i in res:
    if 'BaseVoltage' in str(type(res[i])):
        print(i)
# Out:
# _a5b4e1c5-b844-4a1a-870c-1ee07662d7b4
# _a55f97f1-c485-414c-a845-678fe1eb19cf

# %%
res["_a5b4e1c5-b844-4a1a-870c-1ee07662d7b4"].ConductingEquipment
# Out:
# 'list'

# %%
Terminals = res["N12"].Terminal
for terminal in Terminals:
    print(terminal.ConductingEquipment.mRID)

print(res["TR2"])
# Out:
# L12-13
# TR2
# Load12-H
# Load12-I
# class=PowerTransformer
# DiagramObjects=list
# mRID=TR2
# name=TR2
# description=
# energyIdentCodeEic=
# shortName=
# Controls=list
# Measurements=list
# Location=None
# aggregate=False
# EquipmentContainer=class=Substation
# DiagramObjects=list
# mRID=_3FA2-2E-F1-00000000000000003431
# name=N0
# description=
# energyIdentCodeEic=
# shortName=
# Controls=list
# Measurements=list
# Location=None
# ConnectivityNodes=list
# TopologicalNode=list
# Equipments=list
# DCConverterUnit=list
# Region=class=SubGeographicalRegion
# DiagramObjects=list
# mRID=_33f5b8ba-2a5d-445d-85e2-714736e3087d
# name=Zone 1
# description=
# energyIdentCodeEic=
# shortName=
# DCLines=list
# Region=class=GeographicalRegion
# DiagramObjects=list
# mRID=_6ed30243-96d0-4ff3-9d4c-ef272ceb2bb0
# name=Area 1
# description=
# energyIdentCodeEic=
# shortName=
# Regions=list
#
# Lines=list
# Substations=list
#
# VoltageLevels=list
#
# OperationalLimitSet=[<cimpy.cgmes_v2_4_15.OperationalLimitSet.OperationalLimitSet object at 0x7f9608e44310>, <cimpy.cgmes_v2_4_15.OperationalLimitSet.OperationalLimitSet object at 0x7f9608ec9400>]
# BaseVoltage=None
# Terminals=list
# SvStatus=None
# PowerTransformerEnd=[<cimpy.cgmes_v2_4_15.PowerTransformerEnd.PowerTransformerEnd object at 0x7f9608e44d60>, <cimpy.cgmes_v2_4_15.PowerTransformerEnd.PowerTransformerEnd object at 0x7f9608e44b80>]
# beforeShCircuitHighestOperatingCurrent=0.0
# beforeShCircuitHighestOperatingVoltage=0.0
# beforeShortCircuitAnglePf=0.0
# highSideMinOperatingU=0.0
# isPartOfGeneratorUnit=False
# operationalValuesConsidered=False

# %%
mydict = dict()

pi_line = dpsimpy.sp.ph1.PiLine("mRID36", dpsimpy.LogLevel.debug)
pi_line.name
pi_line.set_base_voltage(89)
mydict[pi_line.name] = pi_line

mydict
com_list = list(mydict.values())
n1 = dpsimpy.sp.SimNode("Node 1", dpsimpy.PhaseType.Single)
n2 = dpsimpy.sp.SimNode("Node 2", dpsimpy.PhaseType.Single)
frequency = 60





pi_line.connect([n1,n2])
nodes = dict()
nodes[n1.name]= n1
nodes[n2.name]= n2
node_list = list(nodes.values())

system1 = dpsimpy.SystemTopology(frequency, node_list, com_list)
dpsimpy.SystemTopology.connect_component(system1,pi_line, [n1])
#connect_component_to_node( system,pi_line, n1)

system1

# %%
pi_line1 = dpsimpy.sp.ph1.PiLine("Line1", dpsimpy.LogLevel.debug)

n1 = dpsimpy.sp.SimNode("Node 1", dpsimpy.PhaseType.Single)
n2 = dpsimpy.sp.SimNode("Node 2", dpsimpy.PhaseType.Single)

pi_line1.connect([n1])
pi_line1.connect([n1,n2])

system1 = dpsimpy.SystemTopology(60, [n1,n2], [pi_line1])
system1
pi_line1.print_attribute_list()
# Out:
# Attribute list for object with name Line1:
# name                          type                size           value
# -----------------------------------------------------------------------------------------------
# C_parallel                    Real                               0.000000
# G_parallel                    Real                               0.000000
# L_series                      Real                               0.000000
# R_series                      Real                               0.000000
# base_Voltage                  Real                               0.000000
# current_vector                MatrixComplex       2x1            [...]
# i_intf                        MatrixComplex       1x1            [...]
# name                          String                             "Line1"
# p_branch_vector               MatrixReal          2x1            [...]
# p_inj                         Real                               0.000000
# q_branch_vector               MatrixReal          2x1            [...]
# q_inj                         Real                               0.000000
# right_vector                  MatrixReal          0x0            [...]
# uid                           String                             "Line1"
# v_intf                        MatrixComplex       1x1            [...]

# %%
n = dpsimpy.sp.ph1.PiLine.get_terminal(pi_line,1).print_attribute_list()

#dpsimpy.SimTerminalComplex.print_attribute_list
# Out:
# Attribute list for object with name mRID36_T1:
# name                          type                size           value
# -----------------------------------------------------------------------------------------------
# name                          String                             "mRID36_T1"
# uid                           String                             "mRID36_T1"

# %%
'''
pi_line = dpsimpy_components.PiLine(res[i].mRID, dpsimpy.LogLevel.debug)
Connection_Nodes = []
for terminal in res[i].Terminals:
    node = Nodes[terminal.TopologicalNode.mRID]
    Connection_Nodes.append(node)
pi_line.connect(Connection_Nodes)
'''
# Out:
# '\npi_line = dpsimpy_components.PiLine(res[i].mRID, dpsimpy.LogLevel.debug)\nConnection_Nodes = []\nfor terminal in res[i].Terminals:\n    node = Nodes[terminal.TopologicalNode.mRID]\n    Connection_Nodes.append(node)\npi_line.connect(Connection_Nodes)\n'

# %%
Components_Dict = dict()

Components_Dict["L1234"]= {"Trafo": "jdv", "Nodes" : ["sfs", 134]}
Components_Dict["L84"]= {"Trafo": "j24dv", "Nodes" : ["sfs", 134], "AnoterOne":[]}
Components_Dict["L1234"]["Nodes"].append(1)
Components_Dict
CList =[]
for j in Components_Dict:
    CList.append(Components_Dict[j]["Trafo"])

Components_Dict
# Out:
# {'L1234': {'Trafo': 'jdv', 'Nodes': ['sfs', 134, 1]},
#  'L84': {'Trafo': 'j24dv', 'Nodes': ['sfs', 134], 'AnoterOne': []}}

# %%
NDic = dict([])
NDic["xalo"]= []
NDic
# Out:
# {'xalo': []}
